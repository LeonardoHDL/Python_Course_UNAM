# %%
#10/0
try:
    10/0
except:
    print('jaja como crees que se puede dividir entre 0')
# Out:
# jaja como crees que se puede dividir entre 0

# %%
#List index out of range
lista=[1,2,3]
try:
    lista[10]
except:
    print('fuera del rango jajaja')
# Out:
# fuera del rango jajaja

# %%
#Key not in  dict
colores = { 'rojo':'red', 'verde':'green', 'negro':'black' }
try:
    colores['amarillo purpura']
except:
    print('nosta ese nombre')
# Out:
# nosta ese nombre

# %%
# int + str not valid
try:
    print(15+'20')
except:
    print('son de diferente tipo jeje, no se puede')
# Out:
# son de diferente tipo jeje, no se puede
