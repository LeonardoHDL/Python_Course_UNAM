# %% [markdown]
# **Ejercicio 1.** Utilizando operadores lógicos, determina si una cadena de texto introducida por el usuario tiene una longitud mayor o igual que 3 y a su vez es menor que 10 (es suficiene con mostrar True o False):

# %%
# Escriba su código aquí
a=input(f'introduzca texto')
if 3<=len(a)<10:
    print(True)
else:
    print(False)
# Out:
# introduzca texto HOLA JEJE
# True

# %% [markdown]
# **Ejercicio 2.**  Realiza un programa que lea 2 números por teclado y determine los siguientes aspectos (es suficiene con mostrar True o False):
#
# - Si los dos números son iguales
# - Si los dos números son diferentes
# - Si el primero es mayor que el segundo
# - Si el segundo es mayor o igual que el primero

# %%
a,b=int(input('Introduce un numero')), int(input("introduce otro numero"))
print(f'los numeros son iguales: {a==b}')
print(f'los numeros son diferentes: {a!=b}')
print(f'el primer numero es mayor que el segundo: {a>b}')
print(f'el segundo es mayor o igual que el primero: {b>=a}')
# Out:
# Introduce un numero 1
# introduce otro numero 2
# los numeros son iguales: False
# los numeros son diferentes: True
# el primer numero es mayor que el segundo: False
# el segundo es mayor o igual que el primero: True
